# %%
import jax
import jax.numpy as jnp
from jax import grad, vmap, jit, random
import optax
import equinox as eqx
import matplotlib.pyplot as plt
from typing import List

# %%
#the first thing jax does differently is PRD
#we can create 'random' but fully repeatable experiemnts
#we generate a key, then we split it for each call.
#this split is you can simply replace the 0 with a wall clock call for "true determism"

#lets create 4 news keys (5 total)
key = jax.random.PRNGKey(0)
key, trainkey, testkey, noisekey1, noisekey2 = jax.random.split(key,5)

#pick our number of training and test samples
num_train = 5000
num_test = 2000

#get some random training points
train_data = jax.random.uniform(trainkey, (num_train,1), minval=-3*jnp.pi, maxval=3*jnp.pi)
test_data = jax.random.uniform(testkey, (num_test,1), minval=-10*jnp.pi, maxval=10*jnp.pi)

#compute our random target points
train_target = jnp.sin(train_data)
test_target = jnp.sin(test_data)
train_target_noisy = train_target + jax.random.normal(noisekey1, (num_train,1))*0.1
test_target_noisy = test_target + jax.random.normal(noisekey2, (num_test,1))*0.1

# %%
#plot to see what they look like
plt.scatter(train_data,train_target)
plt.show()
plt.scatter(train_data,train_target_noisy)
plt.show()
plt.scatter(test_data,test_target)
plt.show()
plt.scatter(test_data,test_target_noisy)
plt.show()

# %%
#define a simple feed forward neural network
#the input and output will be size 1
#we want 3 hidden layers of size 10
architecture = [1,10,10,10,1]

#we are going to use the following nice trick for defining our network
#zip does what it says, zips things into a tuple
#we then take the first 4 and the last 4 of layers and combine them
#so we get (1,10), (10,10) ... (10,1)
#that is exactly the sizing we want for each of our layers
for (f_in,f_out) in zip(architecture[:-1], architecture[1:]):
    print(f_in,f_out)
# Out:
# 1 10
# 10 10
# 10 10
# 10 1

# %%
#explicit model relying on a linear layer
class simpleModel(eqx.Module):
    #what is in our model? a stack of linear layers
    #we don't know how many, so lets just specify it as a list of them
    layers: List[eqx.nn.Linear]
    #we need an initialization method
    #what do we want
    #a prd key for initialization L R^in -> R^out: W(in)+b
    #and we need our layers.
    def __init__(self, architecture, key):
        self.layers = []
        for (f_in, f_out) in zip(architecture[:-1], architecture[1:]):
            key, subkey = jax.random.split(key)
            self.layers.append(
                eqx.nn.Linear(
                    f_in,
                    f_out,
                    use_bias = True,
                    key = subkey
                )
            )
    #now we need a way to call the neural network
    #we pass the key even if it isn't being used by convention
    def __call__(self, x):
        a = x
        for layer in self.layers[:-1]:
            a = jax.nn.sigmoid(layer(a))
        a = self.layers[-1](a)
        return a

#lets create our first model by calling this class
model = simpleModel(architecture, key)

# %%
#lets try caling our nice model
model(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/z6/ct5rgt617tq3x51g1n_scw340000gn/T/ipykernel_22951/3864096050.py in ?()
#       1 #lets try caling our nice model
# ----> 2 model(1)
#
# /var/folders/z6/ct5rgt617tq3x51g1n_scw340000gn/T/ipykernel_22951/3172480191.py in ?(self, x)
#      24     def __call__(self, x):
#      25         a = x
#      26         for layer in self.layers[:-1]:
# ---> 27             a = jax.nn.sigmoid(layer(a))
#      28         a = self.layers[-1](a)
#      29         return a
#
# /opt/homebrew/anaconda3/envs/condaenv/lib/python3.11/contextlib.py in ?(*args, **kwds)
#      78         @wraps(func)
#      79         def inner(*args, **kwds):
#      80             with self._recreate_cm():
# ---> 81                 return func(*args, **kwds)
#
# /opt/homebrew/anaconda3/envs/condaenv/lib/python3.11/site-packages/equinox/nn/_linear.py in ?(self, x, key)
#      91         if self.in_features == "scalar":
#      92             if jnp.shape(x) != ():
#      93                 raise ValueError("x must have scalar shape")
#      94             x = jnp.broadcast_to(x, (1,))
# ---> 95         x = self.weight @ x
#      96         if self.bias is not None:
#      97             x = x + self.bias
#      98         if self.out_features == "scalar":
#
# /opt/homebrew/anaconda3/envs/condaenv/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py in ?(self, other)
#     574     if hasattr(other, '__jax_array__'):
#     575       other = other.__jax_array__()
#     576     args = (other, self) if swap else (self, other)
#     577     if isinstance(other, _accepted_binop_types):
# --> 578       return binary_op(*args)
#     579     # Note: don't use isinstance here, because we don't want to raise for
#     580     # subclasses, e.g. NamedTuple objects that may override operators.
#     581     if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 14 frame]
#
# /opt/homebrew/anaconda3/envs/condaenv/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py in ?(a, b, precision, preferred_element_type)
#    9130   for i, x in enumerate((a, b)):
#    9131     if ndim(x) < 1:
#    9132       msg = (f"matmul input operand {i} must have ndim at least 1, "
#    9133              f"but it has ndim {ndim(x)}")
# -> 9134       raise ValueError(msg)
#    9135   if preferred_element_type is None:
#    9136     preferred_element_type, output_weak_type = dtypes.result_type(a, b, return_weak_type_flag=True)
#    9137   else:
#
# ValueError: matmul input operand 1 must have ndim at least 1, but it has ndim 0

# %%
#and it immediately broke!
#why?
#matmul input operand 1 must have ndim at least 1, but it has ndim 0
#our model takes a "scalar" input but it really wants an R^1 vector
#when we pass it a raw scalar it will explode despite being equivalent mathematically
#this is because the scalar and R^1 vectors are distinct data types
#so we need to turnt his scalar into a R^1 vector
print(jnp.array(1.0))
print(jnp.array([1.0]))
#the second one is the form we want, and so we can use it in our model
model(jnp.array([1]))
# Out:
# 1.0
# [1.]
# Array([0.593246], dtype=float32)

# %%
#ok so now we can toss in our data to see what it looks like on an untrained network
#model(train_data,key)
print(jnp.shape(train_data))
# Out:
# (5000, 1)

# %%
model(train_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model(train_data)
#
# Cell In[10], line 27, in simpleModel.__call__(self, x)
#      25 a = jnp.atleast_1d(x)
#      26 for layer in self.layers[:-1]:
# ---> 27     a = jax.nn.sigmoid(layer(a))
#      28 a = self.layers[-1](a)
#      29 return a
#
# File /opt/homebrew/anaconda3/envs/condaenv/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File /opt/homebrew/anaconda3/envs/condaenv/lib/python3.11/site-packages/equinox/nn/_linear.py:95, in Linear.__call__(self, x, key)
#      93         raise ValueError("x must have scalar shape")
#      94     x = jnp.broadcast_to(x, (1,))
# ---> 95 x = self.weight @ x
#      96 if self.bias is not None:
#      97     x = x + self.bias
#
# File /opt/homebrew/anaconda3/envs/condaenv/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:578, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     576 args = (other, self) if swap else (self, other)
#     577 if isinstance(other, _accepted_binop_types):
# --> 578   return binary_op(*args)
#     579 # Note: don't use isinstance here, because we don't want to raise for
#     580 # subclasses, e.g. NamedTuple objects that may override operators.
#     581 if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 14 frame]
#
# File /opt/homebrew/anaconda3/envs/condaenv/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:9185, in matmul(a, b, precision, preferred_element_type)
#    9183 a = lax.squeeze(a, tuple(a_squeeze))
#    9184 b = lax.squeeze(b, tuple(b_squeeze))
# -> 9185 out = lax.dot_general(
#    9186   a, b, (((ndim(a) - 1,), (ndim(b) - 1 - b_is_mat,)), (a_batch, b_batch)),
#    9187   precision=precision, preferred_element_type=preferred_element_type)
#    9188 result = lax.transpose(out, perm)
#    9189 return lax_internal._convert_element_type(result, preferred_element_type, output_weak_type)
#
#     [... skipping hidden 7 frame]
#
# File /opt/homebrew/anaconda3/envs/condaenv/lib/python3.11/site-packages/jax/_src/lax/lax.py:3518, in _dot_general_shape_rule(lhs, rhs, dimension_numbers, precision, preferred_element_type, out_sharding)
#    3515 if not core.definitely_equal_shape(lhs_contracting_shape, rhs_contracting_shape):
#    3516   msg = ("dot_general requires contracting dimensions to have the same "
#    3517          "shape, got {} and {}.")
# -> 3518   raise TypeError(msg.format(lhs_contracting_shape, rhs_contracting_shape))
#    3520 return _dot_general_shape_computation(lhs.shape, rhs.shape, dimension_numbers)
#
# TypeError: dot_general requires contracting dimensions to have the same shape, got (1,) and (5000,).

# %%
#and it expoded again
#you might guess the reason for this, our dimensions aren't right again
#the network wants an R^1 vector
#we instead gave it a "batch" of 5000 R^1 vectors
#that is R^5000, giving us the error
#dot_general requires contracting dimensions to have the same shape, got (1,) and (5000,).
#how do we fix this? using JAX's vmap command
vecmodel = jax.vmap(model, in_axes = 0)
plt.scatter(train_data, vecmodel(train_data))

# %%
class simpleMLP(eqx.Module):
    layer: eqx.nn.MLP

    def __init__(self, key, f_in, f_out, f_width, f_hidden, activation = jax.nn.sigmoid):
        self.layer = eqx.nn.MLP(
            f_in,
            f_out,
            f_width,
            f_hidden,
            activation = activation,
            use_bias=True,
            key = key)
    def __call__(self, x):
        a = x
        a = self.layer(a)
        return a

# %%
model1key, key = jax.random.split(key)
model1 = simpleMLP(model1key, 1, 1, 10, 3)

# %%
plt.scatter(train_data, jax.vmap(model1)(train_data))

# %%
import optax

# %%
# Define loss function
def loss_fn(model, x, y):
    y_pred = jax.vmap(model)(x)
    loss = jnp.mean(jnp.square(y_pred - y))
    return loss
# Initialize optimizer
learning_rate = 3e-4
optimizer = optax.adam(learning_rate)
opt_state = optimizer.init(eqx.filter(model1, eqx.is_array))

# Define a single training step
@eqx.filter_jit
def make_step(model, state, x, y):
    loss, grad = eqx.filter_value_and_grad(loss_fn, has_aux=False)(model, x, y)
    updates, new_state = optimizer.update(grad, state, model)
    new_model = eqx.apply_updates(model, updates)
    return new_model, new_state, loss

# %%
# Training loop
